# %%
from selenium import webdriver 
import time
# from matplotlib.pyplot import imshow
# from PIL import Image 
import json
import requests


import cv2
import time
  
# Here Chrome  will be used 
driver = webdriver.Firefox()
  
# URL of website 
url = "https://www.google.com"
  
# Opening the website 
driver.get(url) 
  
driver.save_screenshot("image.png") 
  
# Loading the image 
image = Image.open("image.png") 
  
# # Showing the iamge 
# image.show()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-2-8a8daad77e0e> in <module>
#      17
#      18 # Opening the website
# ---> 19 driver.get(url)
#      20
#      21 driver.save_screenshot("image.png")
#
# ~/Timbuctoo/BattleOfBrands/BattleField/venv/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~/Timbuctoo/BattleOfBrands/BattleField/venv/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/Timbuctoo/BattleOfBrands/BattleField/venv/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: TypeError: this.curBrowser.contentBrowser is null

# %%
web

# %%
while True:

    driver.save_screenshot("image.png") 
    image = cv2.imread("image.png")

    image = cv2.resize(image, (250, 174)) 
    cv2.imshow('Game', image)
    
    time.sleep(0.25)
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-07cb1c8b78a7> in <module>
#       2
#       3     driver.save_screenshot("image.png")
# ----> 4     image = cv2.imread("image.png")
#       5
#       6     image = cv2.resize(image, (250, 174))
#
# KeyboardInterrupt:

# %%
while True:
    driver.save_screenshot("image.png") 
    # Loading the image 
    image = Image.open("image.png") 
    imshow(image, cmap='gray')
    print(image)
    calc_impact("image.png")
#     image.show() 
    image.
    time.sleep(2)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x11D55B400>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 5, "y": 148, "w": 74, "h": 37}}]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x1045F3EE0>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 1014, "y": 123, "w": 67, "h": 25}}]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x104600070>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 920, "y": 79, "w": 89, "h": 33}}]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x1046003D0>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 342, "y": 350, "w": 68, "h": 23}}]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x1046004C0>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 697, "y": 536, "w": 34, "h": 43}}]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x104600880>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 725, "y": 220, "w": 90, "h": 35}}]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x1046008B0>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 472, "y": 318, "w": 40, "h": 36}}]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x10460B190>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 150, "y": 381, "w": 53, "h": 41}}]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x10460B2E0>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 710, "y": 506, "w": 60, "h": 32}}]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x10460B3A0>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 314, "y": 710, "w": 84, "h": 23}}]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x10460B8B0>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 675, "y": 414, "w": 66, "h": 50}}]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x10460B100>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 719, "y": 438, "w": 70, "h": 21}}]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x1046150D0>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 519, "y": 63, "w": 67, "h": 22}}]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x104615640>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 1012, "y": 555, "w": 93, "h": 22}}]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x104615760>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 631, "y": 107, "w": 21, "h": 37}}]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x104615850>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 462, "y": 389, "w": 82, "h": 33}}]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x104615E80>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 541, "y": 510, "w": 94, "h": 20}}]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x104622100>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 1013, "y": 638, "w": 83, "h": 33}}]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x104622670>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 299, "y": 153, "w": 88, "h": 23}}]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x104622790>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 980, "y": 504, "w": 81, "h": 36}}]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x1046222B0>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 466, "y": 7, "w": 28, "h": 28}}]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x104622E50>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 1014, "y": 407, "w": 93, "h": 22}}]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x102404130>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 414, "y": 84, "w": 32, "h": 48}}]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x1024045E0>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 389, "y": 214, "w": 45, "h": 28}}]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x1024047C0>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 213, "y": 602, "w": 93, "h": 46}}]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x102404400>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 920, "y": 547, "w": 57, "h": 50}}]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x1024048B0>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 102, "y": 381, "w": 60, "h": 49}}]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1744 at 0x102410160>
# [{"name": "Microsoft", "visibility": 100, "rectangle": {"x": 218, "y": 403, "w": 56, "h": 27}}]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-5f6f374e870a> in <module>
#       1 while True:
# ----> 2     driver.save_screenshot("image.png")
#       3     # Loading the image
#       4     image = Image.open("image.png")
#       5     imshow(image, cmap='gray')
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in save_screenshot(self, filename)
#    1053             driver.save_screenshot('/Screenshots/foo.png')
#    1054         """
# -> 1055         return self.get_screenshot_as_file(filename)
#    1056
#    1057     def get_screenshot_as_png(self):
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in get_screenshot_as_file(self, filename)
#    1030             warnings.warn("name used for saved screenshot does not match file "
#    1031                           "type. It should end with a `.png` extension", UserWarning)
# -> 1032         png = self.get_screenshot_as_png()
#    1033         try:
#    1034             with open(filename, 'wb') as f:
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in get_screenshot_as_png(self)
#    1062             driver.get_screenshot_as_png()
#    1063         """
# -> 1064         return base64.b64decode(self.get_screenshot_as_base64().encode('ascii'))
#    1065
#    1066     def get_screenshot_as_base64(self):
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in get_screenshot_as_base64(self)
#    1072             driver.get_screenshot_as_base64()
#    1073         """
# -> 1074         return self.execute(Command.SCREENSHOT)['value']
#    1075
#    1076     def set_window_size(self, width, height, windowHandle='current'):
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      73
#      74         if method in self._encode_url_methods:
# ---> 75             return self.request_encode_url(
#      76                 method, url, fields=fields, headers=headers, **urlopen_kw
#      77             )
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/urllib3/request.py in request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      95             url += "?" + urlencode(fields)
#      96
# ---> 97         return self.urlopen(method, url, **extra_kw)
#      98
#      99     def request_encode_body(
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     334             response = conn.urlopen(method, url, **kw)
#     335         else:
# --> 336             response = conn.urlopen(method, u.request_uri, **kw)
#     337
#     338         redirect_location = redirect and response.get_redirect_location()
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in getresponse(self)
#    1320         try:
#    1321             try:
# -> 1322                 response.begin()
#    1323             except ConnectionError:
#    1324                 self.close()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x117f95430> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2208
#    2209             try:
# -> 2210                 result = print_method(
#    2211                     filename,
#    2212                     dpi=dpi,
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     507             *metadata*, including the default 'Software' key.
#     508         """
# --> 509         FigureCanvasAgg.draw(self)
#     510         mpl.image.imsave(
#     511             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     405              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     406               else nullcontext()):
# --> 407             self.figure.draw(self.renderer)
#     408             # A GUI class may be need to update a window using this draw, so
#     409             # don't forget to call the superclass.
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1861
#    1862             self.patch.draw(renderer)
# -> 1863             mimage._draw_list_compositing_images(
#    1864                 renderer, self, artists, self.suppressComposite)
#    1865
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2745             renderer.stop_rasterizing()
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#    2749         renderer.close_group('axes')
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/matplotlib/image.py in draw(self, renderer, *args, **kwargs)
#     639                 renderer.draw_image(gc, l, b, im, trans)
#     640         else:
# --> 641             im, l, b, trans = self.make_image(
#     642                 renderer, renderer.get_image_magnification())
#     643             if im is not None:
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/matplotlib/image.py in make_image(self, renderer, magnification, unsampled)
#     924         clip = ((self.get_clip_box() or self.axes.bbox) if self.get_clip_on()
#     925                 else self.figure.bbox)
# --> 926         return self._make_image(self._A, bbox, transformed_bbox, clip,
#     927                                 magnification, unsampled=unsampled)
#     928
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/matplotlib/image.py in _make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     550                 output_alpha = _resample(  # resample alpha channel
#     551                     self, A[..., 3], out_shape, t, alpha=alpha)
# --> 552                 output = _resample(  # resample rgb channels
#     553                     self, _rgb_to_rgba(A[..., :3]), out_shape, t, alpha=alpha)
#     554                 output[..., 3] = output_alpha  # recombine rgb and alpha
#
# ~/Timbuctoo/BattleOfBrands/ImpactGeneration/venv/lib/python3.8/site-packages/matplotlib/image.py in _resample(image_obj, data, out_shape, transform, resample, alpha)
#     190     if resample is None:
#     191         resample = image_obj.get_resample()
# --> 192     _image.resample(data, out, transform,
#     193                     _interpd_[interpolation],
#     194                     resample,
#
# KeyboardInterrupt:

# %%
def calc_impact(image_url):
    url = "http://127.0.0.1:8000/process_image/"

    payload = {}
    files = [
      ('files', open(image_url,'rb'))
    ]
    headers= {}
    response = requests.request("POST", url, headers=headers, data = payload, files = files)
    test = json.loads(response.text)
    
    print(response.text)
